# %%
import yfinance as yf 
from make_data import make_data

SP500 = yf.download('SPY', keepna = True )
data = make_data(SP500)

data.to_csv('example.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# !python DWT.py
# Out:
# Figure(640x480)
# check the example.png created by this file

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   25.218210
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.397594
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.451406
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.720442
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.828054
# ...                ...         ...         ...         ...         ...
# 2023-03-09  399.739990  401.480011  390.529999  391.559998  391.559998
# 2023-03-10  390.989990  393.160004  384.320007  385.910004  385.910004
# 2023-03-13  381.809998  390.390015  380.649994  385.359985  385.359985
# 2023-03-14  390.500000  393.450012  387.049988  391.730011  391.730011
# 2023-03-15  385.890015  389.489990  383.709991  389.279999  389.279999
#
#                Volume        SMA5        SMA7       SMA14       SMA30  ...  \
# Date                                                                   ...
# 1993-01-29    1003200         NaN         NaN         NaN         NaN  ...
# 1993-02-01     480500         NaN         NaN         NaN         NaN  ...
# 1993-02-02     201300         NaN         NaN         NaN         NaN  ...
# 1993-02-03     529400         NaN         NaN         NaN         NaN  ...
# 1993-02-04     531500   25.523141         NaN         NaN         NaN  ...
# ...               ...         ...         ...         ...         ...  ...
# 2023-03-09  111945300  399.482001  398.565713  398.991431  404.728001  ...
# 2023-03-10  189105300  395.826001  397.304286  397.466431  404.100001  ...
# 2023-03-13  157790000  392.003998  395.525713  396.485716  403.422667  ...
# 2023-03-14  149752400  390.696002  393.745714  395.999287  403.127335  ...
# 2023-03-15  172417900  388.767999  391.575714  395.186430  402.554001  ...
#
#             ForceIndex14  ForceIndex30  ForceIndex60  ForceIndex90       EMV5  \
# Date
# 1993-01-29           NaN           NaN           NaN           NaN        NaN
# 1993-02-01           NaN           NaN           NaN           NaN        NaN
# 1993-02-02           NaN           NaN           NaN           NaN        NaN
# 1993-02-03           NaN           NaN           NaN           NaN        NaN
# 1993-02-04           NaN           NaN           NaN           NaN        NaN
# ...                  ...           ...           ...           ...        ...
# 2023-03-09 -1.871726e+09 -9.840001e+08  8.697898e+06  1.490764e+09  -1.383076
# 2023-03-10 -4.037399e+09 -3.562743e+09 -2.121081e+09 -2.518422e+08 -15.675859
# 2023-03-13 -2.166458e+09 -3.206294e+09 -2.330971e+09  1.444370e+08 -23.422117
# 2023-03-14 -1.019813e+09 -1.326804e+09 -8.752024e+08  1.342932e+09 -13.425315
# 2023-03-15 -1.962117e+09 -2.965590e+09  2.467300e+08  2.779986e+09 -13.368044
#
#                  EMV7     EMV14     EMV30     EMV60     EMV90
# Date
# 1993-01-29        NaN       NaN       NaN       NaN       NaN
# 1993-02-01        NaN       NaN       NaN       NaN       NaN
# 1993-02-02        NaN       NaN       NaN       NaN       NaN
# 1993-02-03        NaN       NaN       NaN       NaN       NaN
# 1993-02-04        NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...
# 2023-03-09  -1.751930 -4.712134  1.647143  2.037583  1.940796
# 2023-03-10  -5.332561 -5.824101 -0.690141  1.374214  1.298024
# 2023-03-13  -8.678999 -5.264157 -2.118102 -0.279429  0.996661
# 2023-03-14 -11.148697 -2.973624 -0.769957  0.606475  1.220345
# 2023-03-15 -15.590260 -3.913867 -1.386826  1.375381  1.708769
#
# [7586 rows x 50 columns]

# %% [markdown]
# ## Test CWT

# %%
from CWT import CWT
from DWT import discrete_wavelet_denoise, log_return
# Out:
# check the example.png created by this file

# %%
k = 30
sample =  data['Adj Close'][:k].to_numpy()
sample_denoised = discrete_wavelet_denoise (sample , wavelet = 'db4', level = 1)
log_ret = log_return(sample_denoised)

# %%
import os 
kwargs = {'b' : 2., 'c' : 1. }
CWT (log_ret,show = True, wavelet = 'cmor',path= 'scalo.png', **kwargs  )
# Out:
# array([[0.00019964, 0.00037115, 0.00030263, ..., 0.00075835, 0.00057454,
#         0.00016932],
#        [0.00042132, 0.0005249 , 0.00052523, ..., 0.00018261, 0.00066266,
#         0.00108986],
#        [0.00028791, 0.00023053, 0.00015885, ..., 0.00228445, 0.00200557,
#         0.00168625],
#        ...,
#        [0.00392354, 0.00055835, 0.00294024, ..., 0.00443989, 0.00035848,
#         0.00294202],
#        [0.00393126, 0.00055945, 0.00294603, ..., 0.00444862, 0.00035919,
#         0.00294781],
#        [0.00056055, 0.0029518 , 0.00083036, ..., 0.00036169, 0.00480239,
#         0.00056322]])

# %% [markdown]
# ##  Generation de NN datasets

# %%
from pipeline import *
# Out:
# check the example.png created by this file

# %%
window_size = 360
level_discrete_wavelet_transform = 1
kwargs = {'b' : 2., 'c' : 1. }
signal = data['Adj Close'].to_numpy()
generate_NN_dataset(
    signal ,
    window_size,
    method_labels = 'mean',
    level_discrete_wavelet_transform = 2,
    discrete_wavelet = 'db4',
    continuous_wavelet = 'cmor',
    **kwargs 
    )
# Out:
#   0%|▎                                                                             | 32/7228 [01:07<4:14:26,  2.12s/it]
#
# KeyboardInterrupt
